# %% [markdown]
# <a href="https://colab.research.google.com/github/anisvasanth/AI-DS/blob/main/anis-aryan(562-573).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# === Sample Diabetes Dataset ===
data = pd.DataFrame({
    'Pregnancies': [6, 1, 8, 1, 0],
    'Glucose': [148, 85, 183, 89, 137],
    'BloodPressure': [72, 66, 64, 66, 40],
    'SkinThickness': [35, 29, 0, 23, 35],
    'Insulin': [0, 0, 0, 94, 168],
    'BMI': [33.6, 26.6, 23.3, 28.1, 43.1],
    'DiabetesPedigree': [0.627, 0.351, 0.672, 0.167, 2.288],
    'Age': [50, 31, 32, 21, 33],
    'Outcome': [1, 0, 1, 0, 1]
})

# Features and target
X = data.iloc[:, :-1]
y = data['Outcome']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardizing the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train model
model = LogisticRegression()
model.fit(X_train, y_train)

# Function to Get User Input and Predict
def predict_diabetes():
    print("\n Enter your health details to predict diabetes:\n")

    pregnancies = int(input("Number of Pregnancies: "))
    glucose = float(input("Glucose Level: "))
    blood_pressure = float(input("Blood Pressure: "))
    skin_thickness = float(input("Skin Thickness: "))
    insulin = float(input("Insulin Level: "))
    bmi = float(input("Body Mass Index (BMI): "))
    diabetes_pedigree = float(input("Diabetes Pedigree Function: "))
    age = int(input("Age: "))

    # Convert input into array and standardize
    user_data = np.array([[pregnancies, glucose, blood_pressure, skin_thickness, insulin, bmi, diabetes_pedigree, age]])
    user_data_scaled = scaler.transform(user_data)

    # Predict Outcome
    prediction = model.predict(user_data_scaled)[0]
    probability = model.predict_proba(user_data_scaled)[0][1] * 100  # Probability of having diabetes

    # Display Prediction
    print("\n **Prediction Result**:")
    if prediction == 1:
        print(" You **might have diabetes**. Please consult a doctor.")
    else:
        print(" You **likely do not have diabetes**. Stay healthy!")

    print(f" Probability of Diabetes: {probability:.2f}%")

    # Graphical Representation
    labels = ['No Diabetes', 'Diabetes']
    values = [100 - probability, probability]
    colors = ['green', 'red']

    plt.figure(figsize=(6, 4))
    plt.bar(labels, values, color=colors, alpha=0.7)
    plt.ylabel("Probability (%)")
    plt.title("Diabetes Prediction Probability")
    plt.show()

# Run the Prediction Function
predict_diabetes()
# Out:
#  Enter your health details to predict diabetes:
#
# Number of Pregnancies: 4
# Glucose Level: 43
# Blood Pressure: 50
# Skin Thickness: 23
# Insulin Level: 21
# Body Mass Index (BMI): 10.3
# Diabetes Pedigree Function: 3.25
# Age: 32
#
#  **Prediction Result**:
#  You **might have diabetes**. Please consult a doctor.
#  Probability of Diabetes: 98.34%
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset with simulated years from 2020 to 2024
data_dict = {
    'Year': [2020, 2021, 2022, 2023, 2024],
    'Pregnancies': [6, 1, 8, 1, 0],
    'Glucose': [148, 85, 183, 89, 137],
    'BloodPressure': [72, 66, 64, 66, 40],
    'SkinThickness': [35, 29, 0, 23, 35],
    'Insulin': [0, 0, 0, 94, 168],
    'BMI': [33.6, 26.6, 23.3, 28.1, 43.1],
    'DiabetesPedigreeFunction': [0.627, 0.351, 0.672, 0.167, 2.288],
    'Age': [50, 31, 32, 21, 33],
    'Outcome': [1, 0, 1, 0, 1]
}

# Create DataFrame
data = pd.DataFrame(data_dict)

# Plotting the bar graph using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Glucose', data=data, palette='viridis')

# Customize the plot
plt.title('Year-wise Glucose Levels (2020-2024)')
plt.xlabel('Year')
plt.ylabel('Glucose Level')

# Show the plot
plt.show()
# Out:
# <ipython-input-6-03c479a74bd7>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='Glucose', data=data, palette='viridis')
